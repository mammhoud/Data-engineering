# %% [markdown]
# The mean (average) of a data set is found by adding all numbers in the data set and then dividing by the number of values in the set. The median is the middle value when a data set is ordered from least to greatest. The mode is the number that occurs most often in a data set.

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
df = pd.read_csv (r'data_housing.csv')
df2 = pd.read_csv(r'data_housing_P2.csv')

# %%
df.head(4)
# Out:
#                     ID      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  ID61200236#5/2/2014   313000.0         3       1.50         1340      7912
# 1  ID93053905#5/2/2014  2384000.0         5       2.50         3650      9050
# 2  ID72057649#5/2/2014   342000.0         3       2.00         1930     11947
# 3  ID53221538#5/2/2014   420000.0         3       2.25         2000      8030
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
#
#    yr_renovated                    street       city  statezip country
# 0        2005.0      18810 Densmore Ave N  Shoreline  WA 98133     USA
# ...

# %%
df2.head(4)
# Out:
#            ID      Date  Primary offering  For_Sale
# 0  ID61200236  5/2/2014          438200.0         0
# 1  ID93053905  5/2/2014         3337600.0         0
# 2  ID72057649  5/2/2014          410400.0         0
# 3  ID53221538  5/2/2014          546000.0         1

# %%
df2.describe()
# Out:
#        Primary offering     For_Sale
# count      4.783000e+03  4783.000000
# mean       1.884309e+06     0.476688
# std        6.027124e+06     0.499508
# min        0.000000e+00     0.000000
# 25%        4.080000e+05     0.000000
# 50%        5.902000e+05     0.000000
# 75%        8.645500e+05     1.000000
# max        3.190800e+07     1.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4783 entries, 0 to 4782
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                4783 non-null   object
#  1   Date              4783 non-null   object
#  2   Primary offering  4783 non-null   float64
#  3   For_Sale          4783 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 149.6+ KB

# %% [raw]
# Insert ID for the measure and concat with Date
# Price = zero => not needed
# Postal code plot
# Seattle with trailing space
# ID with join on
# Seattle is NA for some values
# Yr_Renovated => NA some values
# Data types
#
#
# Insights:
# 1- Duplicates affecting the view price (Fifth)
# 2- Seattle is mode (Fourth)
# 3- Seattle is having a trailing edge (Third)
# 4- Price is zero (sixth)
# 5- Split on ID + Join on ID (First)
# 6- Yr_renovated => 0
# 7- Park date and ID to use the ID (Second)
# 8- Export (Eighth)

# %%
#lets explore for the purpose of fixing
print(df.describe())
print(df.shape) # 
print(df.dtypes) #Type of variables 
df.head(2) #Show sample 
df2.info()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.783000e+03  4783.000000  4783.000000   4783.000000  4.783000e+03
# mean   1.548191e+06     3.385532     2.154662   2102.641857  1.458242e+04
# std    5.025766e+06     0.894600     0.769257    962.359614  3.521717e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.277500e+05     3.000000     1.750000   1400.000000  5.100000e+03
# 50%    4.750000e+05     3.000000     2.250000   1940.000000  7.793000e+03
# 75%    6.875000e+05     4.000000     2.500000   2590.000000  1.079300e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4783.000000  4783.000000  4783.000000  4783.000000  4783.000000
# mean      1.492473     0.006899     0.231445     3.472716  1802.500732
# std       0.536951     0.082784     0.764760     0.672422   854.580763
# ...

# %%
#lets explore for the purpose of fixing
print(df2.describe())
print(df2.shape) # Dimentions
print(df2.dtypes) #Type of variables 
print(df2.head(2)) #Show sample 
print(df2.tail(2))

# %%
df.head(2)
# Out:
#                     ID      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  ID61200236#5/2/2014   313000.0         3        1.5         1340      7912
# 1  ID93053905#5/2/2014  2384000.0         5        2.5         3650      9050
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
#
#    yr_renovated                street       city  statezip country
# 0        2005.0  18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1           NaN       709 W Blaine St   Seattle   WA 98119     USA

# %%
#attempt 1 is to join both on ID >> First parse the column in P1
df[['ID_New','Date']] = df['ID'].str.split('#',expand=True)

# %%
df.head(2)
# Out:
#                     ID      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  ID61200236#5/2/2014   313000.0         3        1.5         1340      7912
# 1  ID93053905#5/2/2014  2384000.0         5        2.5         3650      9050
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
#
#    yr_renovated                street       city  statezip country  \
# 0        2005.0  18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1           NaN       709 W Blaine St   Seattle   WA 98119     USA
#
#        ID_New      Date
# 0  ID61200236  5/2/2014
# 1  ID93053905  5/2/2014

# %%
df2.head(2)
# Out:
#            ID      Date  Primary offering  For_Sale
# 0  ID61200236  5/2/2014          438200.0         0
# 1  ID93053905  5/2/2014         3337600.0         0

# %%
#Now we need to merge and join both parts
#first renaming 
df2 = df2.rename(columns={'ID': 'ID_New'})

# %%
df2.head(2)
# Out:
#        ID_New      Date  Primary offering  For_Sale
# 0  ID61200236  5/2/2014          438200.0         0
# 1  ID93053905  5/2/2014         3337600.0         0

# %%
df3 = df.join(df2, lsuffix="_left", rsuffix="_right")

# %%
df3.head(2)
# Out:
#                     ID      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  ID61200236#5/2/2014   313000.0         3        1.5         1340      7912
# 1  ID93053905#5/2/2014  2384000.0         5        2.5         3650      9050
#
#    floors  waterfront  view  condition  ...                street       city  \
# 0     1.5           0     0          3  ...  18810 Densmore Ave N  Shoreline
# 1     2.0           0     4          5  ...       709 W Blaine St   Seattle
#
#    statezip  country ID_New_left Date_left ID_New_right Date_right  \
# 0  WA 98133      USA  ID61200236  5/2/2014   ID61200236   5/2/2014
# 1  WA 98119      USA  ID93053905  5/2/2014   ID93053905   5/2/2014
#
#   Primary offering For_Sale
# 0         438200.0        0
# 1        3337600.0        0
#
# [2 rows x 24 columns]

# %%
df3.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.783000e+03  4783.000000  4783.000000   4783.000000  4.783000e+03
# mean   1.548191e+06     3.385532     2.154662   2102.641857  1.458242e+04
# std    5.025766e+06     0.894600     0.769257    962.359614  3.521717e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.277500e+05     3.000000     1.750000   1400.000000  5.100000e+03
# 50%    4.750000e+05     3.000000     2.250000   1940.000000  7.793000e+03
# 75%    6.875000e+05     4.000000     2.500000   2590.000000  1.079300e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4783.000000  4783.000000  4783.000000  4783.000000  4783.000000
# mean      1.492473     0.006899     0.231445     3.472716  1802.500732
# std       0.536951     0.082784     0.764760     0.672422   854.580763
# ...

# %%
#Now we check for Unique
def unique(list1):
  
    # initialize a null list
    unique_list = []
  
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    # print list
    return unique_list
    for x in unique_list:
        print (x)

# %%
#unique
df3.city.unique()

# %%
print(unique(df3.city))
# Out:
# ['Shoreline', 'Seattle ', 'Kent', 'Bellevue', 'Redmond', 'Maple Valley', 'North Bend', 'Lake Forest Park', 'Sammamish', 'Auburn', 'Des Moines', 'Bothell', 'Federal Way', 'Kirkland', 'Issaquah', 'Woodinville', 'Normandy Park', 'Fall City', 'Renton', 'Carnation', 'Snoqualmie', 'Duvall', 'Burien', 'Covington', 'Inglewood-Finn Hill', 'Kenmore', 'Newcastle', 'Mercer Island', 'Black Diamond', 'Ravensdale', 'Clyde Hill', 'Algona', 'Skykomish', 'Seattle', 'Tukwila', 'Vashon', 'Yarrow Point', 'SeaTac', 'Medina', 'Enumclaw', 'Snoqualmie Pass', 'Pacific', 'Beaux Arts Village', 'Preston', 'Milton', nan]

# %%
#We can see Seattle is repeated with trailing space
#We can also show the count 
df3.groupby('city')['city'].count()
# Out:
# city
# Algona                    5
# Auburn                  176
# Beaux Arts Village        1
# Bellevue                286
# Black Diamond             9
# Bothell                  33
# Burien                   74
# Carnation                22
# Clyde Hill               11
# Covington                43
# Des Moines               58
# Duvall                   42
# Enumclaw                 28
# Fall City                11
# Federal Way             148
# Inglewood-Finn Hill       1
# Issaquah                187
# Kenmore                  66
# Kent                    368
# Kirkland                187
# Lake Forest Park         36
# Maple Valley             96
# Medina                   11
# Mercer Island            86
# Milton                    2
# Newcastle                33
# Normandy Park            18
# North Bend               50
# Pacific                   6
# Preston                   2
# Ravensdale                7
# Redmond                 235
# Renton                  293
# ...

# %%
#Now we use string strip to perform Left & right trimming
df3.city = df3['city'].str.strip()

# %%
#check the strip (Check)
df3.groupby('city')['city'].count()
# Out:
# city
# Algona                    5
# Auburn                  176
# Beaux Arts Village        1
# Bellevue                286
# Black Diamond             9
# Bothell                  33
# Burien                   74
# Carnation                22
# Clyde Hill               11
# Covington                43
# Des Moines               58
# Duvall                   42
# Enumclaw                 28
# Fall City                11
# Federal Way             148
# Inglewood-Finn Hill       1
# Issaquah                187
# Kenmore                  66
# Kent                    368
# Kirkland                187
# Lake Forest Park         36
# Maple Valley             96
# Medina                   11
# Mercer Island            86
# Milton                    2
# Newcastle                33
# Normandy Park            18
# North Bend               50
# Pacific                   6
# Preston                   2
# Ravensdale                7
# Redmond                 235
# Renton                  293
# ...

# %%
#Now we need to check the city nulls and replace them with Mode of City: Seattle
df3.city.isnull().sum()
# Out:
# 48

# %%
mode = df3['city'].mode()
df3['city'] = df3['city'].fillna(mode[0]) #[0] means in the same place
mode
# Out:
# 0    Seattle
# Name: city, dtype: object

# %%
#Delete rows having 3 or more nulls
df3 = df3.dropna(thresh=3)

# %%
df3.shape
# Out:
# (4783, 24)

# %%
df3.city.value_counts()
# Out:
# Seattle                1573
# Kent                    368
# Renton                  293
# Bellevue                286
# Redmond                 235
# Issaquah                187
# Kirkland                187
# Auburn                  176
# Sammamish               175
# Federal Way             148
# Shoreline               123
# Woodinville             115
# Maple Valley             96
# Mercer Island            86
# Burien                   74
# Snoqualmie               71
# Kenmore                  66
# Des Moines               58
# North Bend               50
# Covington                43
# Duvall                   42
# Lake Forest Park         36
# Bothell                  33
# Newcastle                33
# SeaTac                   29
# Tukwila                  29
# Vashon                   29
# Enumclaw                 28
# Carnation                22
# Normandy Park            18
# Clyde Hill               11
# Medina                   11
# Fall City                11
# ...

# %%
df3.city.isnull().sum()
# Out:
# 0

# %%
df3.groupby('city')['city'].count()
# Out:
# city
# Algona                    5
# Auburn                  176
# Beaux Arts Village        1
# Bellevue                286
# Black Diamond             9
# Bothell                  33
# Burien                   74
# Carnation                22
# Clyde Hill               11
# Covington                43
# Des Moines               58
# Duvall                   42
# Enumclaw                 28
# Fall City                11
# Federal Way             148
# Inglewood-Finn Hill       1
# Issaquah                187
# Kenmore                  66
# Kent                    368
# Kirkland                187
# Lake Forest Park         36
# Maple Valley             96
# Medina                   11
# Mercer Island            86
# Milton                    2
# Newcastle                33
# Normandy Park            18
# North Bend               50
# Pacific                   6
# Preston                   2
# Ravensdale                7
# Redmond                 235
# Renton                  293
# ...

# %%
#Now lets check the View with Average Price
df3.groupby('view')['price'].mean()
# Out:
# view
# 0    1.614667e+06
# 1    8.670110e+05
# 2    8.089353e+05
# 3    9.982075e+05
# 4    1.190667e+06
# Name: price, dtype: float64

# %%
#now we can suspect some bias in the price lets check the duplicates
df3[df3.duplicated(['ID'], keep=False)]
# Out:
#                        ID       price  bedrooms  bathrooms  sqft_living  \
# 305   ID60669653#7/3/2014  26590000.0         3        2.0         1180
# 306   ID60669653#7/3/2014  26590000.0         3        2.0         1180
# 307   ID60669653#7/3/2014  26590000.0         3        2.0         1180
# 308   ID60669653#7/3/2014  26590000.0         3        2.0         1180
# 309   ID60669653#7/3/2014  26590000.0         3        2.0         1180
# ...                   ...         ...       ...        ...          ...
# 484   ID60669653#7/3/2014  26590000.0         3        2.0         1180
# 485   ID60669653#7/3/2014  26590000.0         3        2.0         1180
# 486   ID60669653#7/3/2014  26590000.0         3        2.0         1180
# 487   ID60669653#7/3/2014  26590000.0         3        2.0         1180
# 4533  ID60669653#7/3/2014  26590000.0         3        2.0         1180
#
#       sqft_lot  floors  waterfront  view  condition  ...             street  \
# ...

# %%
df4 = df3.drop_duplicates()

# %% [raw]
# keep{‘first’, ‘last’, False}, default ‘first’
# Determines which duplicates (if any) to keep.
# ‘first’ : Drop duplicates except for the first occurrence.
# ‘last’ : Drop duplicates except for the last occurrence.
# False : Drop all duplicates.

# %%
df4[df4.duplicated(['ID'], keep= 'first')]
# Out:
#                        ID       price  bedrooms  bathrooms  sqft_living  \
# 4533  ID60669653#7/3/2014  26590000.0         3        2.0         1180
#
#       sqft_lot  floors  waterfront  view  condition  ...             street  \
# 4533      7793     1.0           0     0          4  ...  12005 SE 219th Ct
#
#       city  statezip  country ID_New_left Date_left ID_New_right Date_right  \
# 4533  Kent  WA 98031      USA  ID60669653  7/3/2014   ID60669653   7/3/2014
#
#      Primary offering For_Sale
# 4533       31908000.0        0
#
# [1 rows x 24 columns]

# %%
#keep in mind this is a price estimator so we need to make sure Price is correct
count_of_zero_Price = (df4['price'] == 0).sum()
count_of_zero_Price
# Out:
# 49

# %%
df5 = df4[df4.price !=0]

# %%
count_of_zero_Price = (df5['price'] == 0).sum()
count_of_zero_Price
# Out:
# 0

# %%
df5.head(5)
# Out:
#                     ID      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  ID61200236#5/2/2014   313000.0         3       1.50         1340      7912
# 1  ID93053905#5/2/2014  2384000.0         5       2.50         3650      9050
# 2  ID72057649#5/2/2014   342000.0         3       2.00         1930     11947
# 3  ID53221538#5/2/2014   420000.0         3       2.25         2000      8030
# 4  ID99016894#5/2/2014   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  ...                    street  \
# 0     1.5           0     0          3  ...      18810 Densmore Ave N
# 1     2.0           0     4          5  ...           709 W Blaine St
# 2     1.0           0     0          4  ...  26206-26214 143rd Ave SE
# 3     1.0           0     0          4  ...           857 170th Pl NE
# 4     1.0           0     0          4  ...         9105 170th Ave NE
#
# ...

# %%
df5.to_csv('out_DWR_Housing.csv')
df5.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.552000e+03  4552.000000  4552.000000   4552.000000  4.552000e+03
# mean   5.636247e+05     3.394552     2.154987   2132.163005  1.483373e+04
# std    6.832423e+05     0.904515     0.776269    955.948901  3.596028e+04
# min    7.800000e+03     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.263464e+05     3.000000     1.750000   1460.000000  5.000000e+03
# 50%    4.650000e+05     3.000000     2.250000   1970.000000  7.680000e+03
# 75%    6.576250e+05     4.000000     2.500000   2610.000000  1.097400e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4552.000000  4552.000000  4552.000000  4552.000000  4552.000000
# mean      1.512083     0.006591     0.234622     3.449473  1822.080624
# std       0.538526     0.080923     0.765296     0.675135   854.412033
# ...

# %%
df5.bedrooms.hist()
df5.view.hist()
# Out:
# <AxesSubplot:>
